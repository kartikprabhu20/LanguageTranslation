# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.model_selection import train_test_split

import unicodedata
import re
import numpy as np
import os
import io
import time

# %% [markdown]
# Data preprocessing from Tensorflow: https://www.tensorflow.org/tutorials/text/nmt_with_attention

# %%
# for colab
from google.colab import drive
drive.mount('/content/drive')
os.chdir("drive/My Drive/Colab Notebooks/IDL2019/")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path_to_zip = tf.keras.utils.get_file(
    'spa-eng.zip', origin='http://storage.googleapis.com/download.tensorflow.org/data/spa-eng.zip',
    extract=True)

path_to_file = os.path.dirname(path_to_zip)+"/spa-eng/spa.txt"

# %%
# Converts the unicode file to ascii
def unicode_to_ascii(s):
  return ''.join(c for c in unicodedata.normalize('NFD', s)
      if unicodedata.category(c) != 'Mn')


def preprocess_sentence(w):
  w = unicode_to_ascii(w.lower().strip())

  # creating a space between a word and the punctuation following it
  # eg: "he is a boy." => "he is a boy ."
  # Reference:- https://stackoverflow.com/questions/3645931/python-padding-punctuation-with-white-spaces-keeping-punctuation
  w = re.sub(r"([?.!,¿])", r" \1 ", w)
  w = re.sub(r'[" "]+', " ", w)

  # replacing everything with space except (a-z, A-Z, ".", "?", "!", ",")
  w = re.sub(r"[^a-zA-Z?.!,¿]+", " ", w)

  w = w.strip()

  # adding a start and an end token to the sentence
  # so that the model know when to start and stop predicting.
  w = '<start> ' + w + ' <end>'
  return w

# %%
en_sentence = u"May I borrow this book?"
sp_sentence = u"¿Puedo tomar prestado este libro?"
print(preprocess_sentence(en_sentence))
print(preprocess_sentence(sp_sentence).encode('utf-8'))
# Out:
# <start> may i borrow this book ? <end>
# b'<start> \xc2\xbf puedo tomar prestado este libro ? <end>'

# %%
# 1. Remove the accents
# 2. Clean the sentences
# 3. Return word pairs in the format: [ENGLISH, SPANISH]
def create_dataset(path, num_examples):
  lines = io.open(path, encoding='UTF-8').read().strip().split('\n')

  word_pairs = [[preprocess_sentence(w) for w in l.split('\t')]  for l in lines[:num_examples]]

  return zip(*word_pairs)

# %%
en, sp = create_dataset(path_to_file, None)
print(en[-1])
print(sp[-1])
# Out:
# <start> if you want to sound like a native speaker , you must be willing to practice saying the same sentence over and over in the same way that banjo players practice the same phrase over and over until they can play it correctly and at the desired tempo . <end>
# <start> si quieres sonar como un hablante nativo , debes estar dispuesto a practicar diciendo la misma frase una y otra vez de la misma manera en que un musico de banjo practica el mismo fraseo una y otra vez hasta que lo puedan tocar correctamente y en el tiempo esperado . <end>

# %%
def tokenize(lang):
  lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
      filters='')
  lang_tokenizer.fit_on_texts(lang) #Create vocabulary

  tensor = lang_tokenizer.texts_to_sequences(lang) #convert text to sequences
  tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                         padding='post')

  return tensor, lang_tokenizer

# %%
def load_dataset(path, num_examples=None):
  # creating cleaned input, output pairs
  targ_lang, inp_lang = create_dataset(path, num_examples)

  input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
  target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

  return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %%
# Try experimenting with the size of that dataset
num_examples = 30000
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(path_to_file, num_examples)

# Calculate max_length of the target tensors
print(input_tensor.shape)
print(target_tensor.shape)
max_length_targ, max_length_inp = target_tensor.shape[1], input_tensor.shape[1]
max_length_targ, max_length_inp
# Out:
# (30000, 16)
# (30000, 11)
# (11, 16)

# %%
# Creating training and validation sets using an 80-20 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(input_tensor, target_tensor, test_size=0.2)

# Show length
print(len(input_tensor_train), len(target_tensor_train), len(input_tensor_val), len(target_tensor_val))
# Out:
# 24000 24000 6000 6000

# %%
input_tensor_train.shape #24000 sentences with less that 16 words per sentence
# Out:
# (24000, 16)

# %%
def convert(lang, tensor):
  for t in tensor:
    if t!=0:
      print ("%d ----> %s" % (t, lang.index_word[t]))

# %%
print ("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print ()
print ("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 28 ----> eso
# 7 ----> es
# 336 ----> dificil
# 14 ----> de
# 354 ----> decir
# 3 ----> .
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 20 ----> that
# 11 ----> s
# 204 ----> hard
# 15 ----> to
# 136 ----> say
# 3 ----> .
# 2 ----> <end>

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 128
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 256
units = 1024
vocab_inp_size = len(inp_lang.word_index)+1
vocab_tar_size = len(targ_lang.word_index)+1
print("Input vocab = ",vocab_inp_size)
print("Target vocab = ",vocab_tar_size)

dataset = tf.data.Dataset.from_tensor_slices((input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True).repeat()
# Out:
# Input vocab =  9414
# Target vocab =  4935

# %%
example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([128, 16]), TensorShape([128, 11]))

# %%
optimizer = tf.keras.optimizers.Adam(lr=0.001)
# loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
#     from_logits=True, reduction='none')
loss_object = tf.losses.SparseCategoricalCrossentropy(from_logits=True)

def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  # print(real.shape)
  # print(pred.shape)

  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %%
# model(encoder)
n_h = 1024
w_xh = tf.Variable(tf.initializers.glorot_uniform()([vocab_inp_size, n_h]))
w_hh = tf.Variable(tf.initializers.glorot_uniform()([n_h, n_h]))
b_h = tf.Variable(tf.zeros([n_h]))

w_ho = tf.Variable(tf.initializers.glorot_uniform()([n_h, vocab_inp_size]))
b_o = tf.Variable(tf.zeros([vocab_inp_size]))


# model(decoder)
d_n_h = 1024
d_w_xh = tf.Variable(tf.initializers.glorot_uniform()([vocab_tar_size, d_n_h]))
d_w_hh = tf.Variable(tf.initializers.glorot_uniform()([d_n_h, d_n_h]))
d_b_h = tf.Variable(tf.zeros([d_n_h]))

d_w_ho = tf.Variable(tf.initializers.glorot_uniform()([d_n_h, vocab_tar_size]))
d_b_o = tf.Variable(tf.zeros([vocab_tar_size]))

all_vars = [w_xh, w_hh, b_h, w_ho, b_o, d_w_xh, d_w_hh, d_b_h, d_w_ho, d_b_o]

# %%
# training
# somewhat arbitrary number of steps
steps = 24000 * 100 // BATCH_SIZE
opt = tf.optimizers.Adam()
# loss_fn = tf.losses.SparseCategoricalCrossentropy(from_logits=True)


@tf.function
def run_rnn_on_seq(inp_batch, target_batch):
    loss = 0.

    with tf.GradientTape() as tape:
        state = tf.zeros([tf.shape(inp_batch)[0], n_h])
        decoder_state = tf.zeros([tf.shape(target_batch)[0], d_n_h])

        # print(state)#(128, 512)
        total_loss = tf.constant(0.)
        for time_step in tf.range(tf.shape(inp_batch)[1]): #sequence size = 16(loop runs 16 times)
            inp_here = tf.one_hot(inp_batch[:, time_step], vocab_inp_size)
            # print(inp_here.shape)#(128,9414)

            state = tf.nn.tanh(tf.matmul(inp_here, w_xh) + tf.matmul(state, w_hh) + b_h)
            encoderlogits = tf.matmul(state, w_ho) + b_o
            decoder_state = state

        dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 0)[0]
        # print(dec_input.shape)#(128, )
        for time_step in tf.range(tf.shape(target_batch)[1]): #target sequence size = 11(loop runs 11 times)
            inp_here = tf.one_hot(dec_input, vocab_tar_size)
            # print(inp_here.shape)#(128,4935)

            decoder_state = tf.nn.tanh(tf.matmul(inp_here, d_w_xh) + tf.matmul(decoder_state, d_w_hh) + d_b_h)
            logits = tf.matmul(decoder_state, d_w_ho) + d_b_o
            # print(logits.shape)
            # print(target_batch[:, time_step].shape)

            loss += loss_function(target_batch[:, time_step], logits)

            # using teacher forcing
            dec_input = target_batch[:, time_step]
                
        batch_loss = loss /tf.cast(tf.shape(target_batch)[1] - 1, tf.float32)

    grads = tape.gradient(batch_loss, all_vars)
    # this is gradient clipping
    # glob_norm = tf.linalg.global_norm(grads)
    # grads = [g/glob_norm for g in grads]
    
    optimizer.apply_gradients(zip(grads, all_vars))    
    return batch_loss

# %%
def evaluate(sentence):
  sentence = preprocess_sentence(sentence)

  inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
  inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                         maxlen=max_length_inp,
                                                         padding='post')
  inp_batch = tf.convert_to_tensor(inputs)
  # print(inputs.shape)#(1,16)
  result = ''

  enc_state = tf.zeros([tf.shape(inp_batch)[0], n_h])
  decoder_state = tf.zeros([1, d_n_h])
 
  for time_step in tf.range(tf.shape(inp_batch)[1]): #sequence size = 16(loop runs 16 times)
    inp_here = tf.one_hot(inp_batch[:, time_step], vocab_inp_size)
            # print(inp_here.shape)#(128,9414)

    enc_state = tf.nn.tanh(tf.matmul(inp_here, w_xh) + tf.matmul(enc_state, w_hh) + b_h)
    encoderlogits = tf.matmul(enc_state, w_ho) + b_o
    decoder_state = enc_state          
  
  dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)[0]
  translation = [targ_lang.word_index['<start>']]

  for time_step in range(max_length_targ):
    inp_here = tf.one_hot(dec_input, vocab_tar_size)
    decoder_state = tf.nn.tanh(tf.matmul(inp_here, d_w_xh) + tf.matmul(decoder_state, d_w_hh) + d_b_h)
    logits = tf.matmul(decoder_state, d_w_ho) + d_b_o
    # print(logits[0].shape)

    # outputs = tf.nn.softmax(logits[0])
    # print(outputs.shape)
    # predicted_id = np.random.choice(vocab_tar_size, p=outputs) 
    predicted_id =tf.argmax(logits[0]).numpy()
   
    if predicted_id == targ_lang.word_index['<end>']:
      result =  "".join([targ_lang.index_word[ind] + " " for ind in translation])
      return result, sentence

    translation.append(predicted_id)
    # the predicted ID is fed back into the model
    dec_input = tf.expand_dims([predicted_id], 0)[0]
      
  result =  "".join([targ_lang.index_word[ind] + " " for ind in translation])

  return result, sentence

# %%
def translate(sentence):
  result, sentence = evaluate(sentence)

  print('Input: %s' % (sentence))
  print('Predicted translation: {}'.format(result))

# %%
for step, seqs in enumerate(dataset):
    inp = seqs[0]
    tar = seqs[1]
    # print(inp.shape)#(128, 16)
    # print(tar.shape)#(128, 11)

    xent_avg = run_rnn_on_seq(inp, tar)

    if not step % 200:
        print("Step: {} Loss: {}".format(step, xent_avg))
        translate(u'hace mucho frio aqui.')
        #Input: <start> hace mucho frio aqui . <end>
        #Actual translation: it s very cold here . <end>

        translate(u'esta es mi vida.')
        #Actual translation: this is my life . <end> 
        
        translate(u'¿todavia estan en casa?')
        #Actual translation: are you still home ? <end> 

        translate(u'trata de averiguarlo.')
        #Actual translation: try to figure it . <end> 
        print("===============================================")
        
    if step > steps:
        break
# Out:
# Step: 0 Loss: 5.831695079803467
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> i am wig . .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> i open lady . .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> i am deserves . .
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> i am familiar . .
# ===============================================
# Step: 200 Loss: 2.1078898906707764
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> i m to .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> tom is a .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> are you you ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> the me .
# ===============================================
# Step: 400 Loss: 1.7401422262191772
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s a good .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> tom s a good .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> are you like ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> come on the room .
# ===============================================
# Step: 600 Loss: 1.5473171472549438
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s a good day .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> that s my car .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> are you a teacher ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> look tom .
# ===============================================
# Step: 800 Loss: 1.393005132675171
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it was very late .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my life .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> can i speak french ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> keep your voice .
# ===============================================
# Step: 1000 Loss: 1.3726695775985718
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s a good job .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my main friend .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> can you have a minute ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> go to the tv .
# ===============================================
# Step: 1200 Loss: 1.1846250295639038
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s very sad .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my car .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> do you have a book ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try , i m a little .
# ===============================================
# Step: 1400 Loss: 1.158434271812439
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s chilly .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my bedroom .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> can t you go ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> my shoes is white .
# ===============================================
# Step: 1600 Loss: 1.1305667161941528
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> i m in the bathroom .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> it s time .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> can i speak french ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> keep your hands up .
# ===============================================
# Step: 1800 Loss: 1.1374526023864746
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s hot today .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my book .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> do you have a book ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> keep warm .
# ===============================================
# Step: 2000 Loss: 1.1083096265792847
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too late .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my car .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> aren t you americans ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> stay here .
# ===============================================
# Step: 2200 Loss: 1.062613844871521
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s been there .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my bedroom .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> can you do that ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to be brave .
# ===============================================
# Step: 2400 Loss: 1.0122239589691162
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s snowing .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my bag .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> isn t it black ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> start singing .
# ===============================================
# Step: 2600 Loss: 0.9945303201675415
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s a hot day .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my coach .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> is tom still right ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try this .
# ===============================================
# Step: 2800 Loss: 1.0228493213653564
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> he is influential .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my house .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> am i included ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> read this .
# ===============================================
# Step: 3000 Loss: 0.86283940076828
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too hot .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my school .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> can you swim like tom ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try this on .
# ===============================================
# Step: 3200 Loss: 0.8772711157798767
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> he is getting old .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my house .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> can i do it ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> read this first .
# ===============================================
# Step: 3400 Loss: 0.8598939180374146
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s a rainy day .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my bedroom .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> isn t that excessive ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try this .
# ===============================================
# Step: 3600 Loss: 0.8893973231315613
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s cold today .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my bedroom .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> are you still sleepy ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try it once more .
# ===============================================
# Step: 3800 Loss: 0.8761257529258728
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too hot .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my home .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> weren t you at home ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to the slower .
# ===============================================
# Step: 4000 Loss: 0.8140663504600525
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s probably tom .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my cat .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> are you still there ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to be strong .
# ===============================================
# Step: 4200 Loss: 0.7923331260681152
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> he is probably angry .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is a joke .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> should i have some water ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to be strong .
# ===============================================
# Step: 4400 Loss: 0.8215295076370239
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s chilly .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my city now .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> may i use your toilet ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to be strong .
# ===============================================
# Step: 4600 Loss: 0.787555992603302
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s getting old .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my book .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> do you have a minute ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try this candy .
# ===============================================
# Step: 4800 Loss: 0.819709300994873
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s chilly .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my mother .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> aren t you happy ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> read this .
# ===============================================
# Step: 5000 Loss: 0.7800149917602539
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s hot over .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is a law .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> are you kidding me ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try this .
# ===============================================
# Step: 5200 Loss: 0.7759666442871094
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too hot here .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my bedroom .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> aren t you tired ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> read this first .
# ===============================================
# Step: 5400 Loss: 0.8103734254837036
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s been a long war .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my life .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> can you hear us ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to think about it .
# ===============================================
# Step: 5600 Loss: 0.7823602557182312
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too late .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is a good camera .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> isn t it black ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try it on , please .
# ===============================================
# Step: 5800 Loss: 0.6605164408683777
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s chilly .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is tom s school .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> do you hear something ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try it once more .
# ===============================================
# Step: 6000 Loss: 0.7342568039894104
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too hot .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my favorite .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> should i quit ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to stay .
# ===============================================
# Step: 6200 Loss: 0.6975060105323792
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too hot .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my coach .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> should i close ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try this on .
# ===============================================
# Step: 6400 Loss: 0.673846423625946
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s dark in here .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my painting .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> aren t you tired ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try it out .
# ===============================================
# Step: 6600 Loss: 0.732521116733551
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too cold .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my painting .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> are you sleepy yet ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to think about it .
# ===============================================
# Step: 6800 Loss: 0.7006714940071106
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s very hot here .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is tom s bedroom .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> weren t you angry ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> read this book .
# ===============================================
# Step: 7000 Loss: 0.6984214782714844
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too hot here .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my question .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> should i be jealous ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try it once more .
# ===============================================
# Step: 7200 Loss: 0.6887747645378113
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s chilly .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my coach .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> aren t you cold ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> read this first .
# ===============================================
# Step: 7400 Loss: 0.7143949866294861
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s very hot here .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my favorite .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> are you still around ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to be strong .
# ===============================================
# Step: 7600 Loss: 0.6706225872039795
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too cold .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my cat .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> did you say yes ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try and calm down .
# ===============================================
# Step: 7800 Loss: 0.708442747592926
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too hot .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my fault .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> aren t you tired ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to stop me .
# ===============================================
# Step: 8000 Loss: 0.7261452674865723
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s hot in here .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my coach .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> aren t you hot ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> strive to be happy .
# ===============================================
# Step: 8200 Loss: 0.7128750085830688
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too hot .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my daughter .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> can you read ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try again .
# ===============================================
# Step: 8400 Loss: 0.6817271709442139
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s unbearably hot .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my home .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> are you still at work ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to find it .
# ===============================================
# Step: 8600 Loss: 0.6925318241119385
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too hot .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is your stop .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> isn t it black ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try again .
# ===============================================
# Step: 8800 Loss: 0.5950272679328918
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s hot down here .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my city now .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> should i be jealous ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try it once more .
# ===============================================
# Step: 9000 Loss: 0.622621476650238
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> that s a blue house .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is our home .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> aren t you tired ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try it on .
# ===============================================
# Step: 9200 Loss: 0.6149634718894958
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too hot .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my mission .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> are you deaf ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try it once more .
# ===============================================
# Step: 9400 Loss: 0.6170448660850525
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too hot .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my house .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> have you taken a bath ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to get some sleep .
# ===============================================
# Step: 9600 Loss: 0.6475492715835571
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s in the house .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my daughter .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> are you still there ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try on .
# ===============================================
# Step: 9800 Loss: 0.6838588118553162
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too hot .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my mission .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> did you say that ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try again .
# ===============================================
# Step: 10000 Loss: 0.6355673670768738
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too cold .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my coach .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> do you still love him ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to figure it out .
# ===============================================
# Step: 10200 Loss: 0.6268351078033447
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too hot .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my brother .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> aren t you ready ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> look ahead .
# ===============================================
# Step: 10400 Loss: 0.6704756617546082
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> that s very handy .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my city now .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> aren t you tired ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to go slower .
# ===============================================
# Step: 10600 Loss: 0.6820651292800903
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s freezing cold .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my life .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> should i include tom ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to be strong .
# ===============================================
# Step: 10800 Loss: 0.6731235384941101
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too cold .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is tom s room .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> aren t you afraid ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to be on time .
# ===============================================
# Step: 11000 Loss: 0.6700521111488342
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s dark .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my bedroom .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> are you still there ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to figure it out .
# ===============================================
# Step: 11200 Loss: 0.6581985354423523
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s unbearably hot .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is homemade jam .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> did tom ask you out ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to be brave , tom .
# ===============================================
# Step: 11400 Loss: 0.6617130041122437
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s very fine .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my daughter .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> do you doubt me ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to be brave , tom .
# ===============================================
# Step: 11600 Loss: 0.5725338459014893
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too cold .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is a good camera .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> do i have permission ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> keep to be brave .
# ===============================================
# Step: 11800 Loss: 0.5210111141204834
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too hot here .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is a good camera .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> are you still there ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> taste this .
# ===============================================
# Step: 12000 Loss: 0.6087514758110046
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s windy .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my office .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> are you able to swim ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try again .
# ===============================================
# Step: 12200 Loss: 0.6038345694541931
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s empty .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is a law .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> isn t that excessive ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try this .
# ===============================================
# Step: 12400 Loss: 0.6538418531417847
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s okay .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is his formula .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> are you still there ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to be on time .
# ===============================================
# Step: 12600 Loss: 0.660858154296875
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> that s very big .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> it s beyond reason .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> are you still there ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try this .
# ===============================================
# Step: 12800 Loss: 0.6025250554084778
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s chilly .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my best friend .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> is it still raining ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to be on time .
# ===============================================
# Step: 13000 Loss: 0.6422142386436462
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s booby trapped .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is tom s bedroom .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> weren t you crying ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to figure it out .
# ===============================================
# Step: 13200 Loss: 0.5945242643356323
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s chilly .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my life .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> are you still married ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to go slower .
# ===============================================
# Step: 13400 Loss: 0.6764183044433594
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s a fine day today .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my coach .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> are you still busy ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to stop me .
# ===============================================
# Step: 13600 Loss: 0.6462623476982117
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> he is cranky .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my dog .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> are you still around ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to think it .
# ===============================================
# Step: 13800 Loss: 0.7039023041725159
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too hot .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> that s my affair .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> did tom come here ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to be on time .
# ===============================================
# Step: 14000 Loss: 0.6360951066017151
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s in the corner .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my coach .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> are you still around ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try it once more .
# ===============================================
# Step: 14200 Loss: 0.6763277649879456
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s nice .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my city now .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> aren t you anxious ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> wow ! that s cheap !
# ===============================================
# Step: 14400 Loss: 0.5853793025016785
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too cold .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my daughter .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> did you say ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to stop me .
# ===============================================
# Step: 14600 Loss: 0.5915035605430603
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s unbearably hot .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is tom s school .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> should i include tom ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to be slower , tom .
# ===============================================
# Step: 14800 Loss: 0.633789598941803
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s very hot here .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my mission .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> is it not black ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to stop me .
# ===============================================
# Step: 15000 Loss: 0.6150843501091003
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too cold .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is a good house .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> aren t you convinced ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to find it .
# ===============================================
# Step: 15200 Loss: 0.6336721777915955
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s very cold here .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is room .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> could you repeat that ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to figure it out .
# ===============================================
# Step: 15400 Loss: 0.7053157687187195
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s worth a fortune .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my favorite .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> don t you know me ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to be on time .
# ===============================================
# Step: 15600 Loss: 0.5809865593910217
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s just cold .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my daughter .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> aren t you sleepy ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to find it .
# ===============================================
# Step: 15800 Loss: 0.6269001364707947
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s very cold .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my bicycle .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> don t you like fish ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to be strong .
# ===============================================
# Step: 16000 Loss: 0.6359698176383972
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s almost over .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my coach .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> aren t you happy ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> examine this .
# ===============================================
# Step: 16200 Loss: 0.6517611742019653
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s dark .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is room .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> is tom still here ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to stop me .
# ===============================================
# Step: 16400 Loss: 0.635653555393219
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s on the sofa .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my bedroom .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> did you notice that ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try it once more .
# ===============================================
# Step: 16600 Loss: 0.6341803073883057
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s chilly .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this room is dark .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> are you still there ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to stop !
# ===============================================
# Step: 16800 Loss: 0.6524950861930847
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s under the chair .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is impossible .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> weren t you relaxed ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to be brave , tom .
# ===============================================
# Step: 17000 Loss: 0.6961507201194763
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too hot .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is tom s room .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> are you still at work ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to be on time .
# ===============================================
# Step: 17200 Loss: 0.7336129546165466
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too cold .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is our only shot .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> isn t it exciting ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to find it .
# ===============================================
# Step: 17400 Loss: 0.638620138168335
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s broken .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my bag .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> aren t you tired ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to go slower .
# ===============================================
# Step: 17600 Loss: 0.5991265773773193
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s hot today .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my house .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> did you miss me ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to be brave .
# ===============================================
# Step: 17800 Loss: 0.6853814125061035
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too cold .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> that s tom s .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> isn t it enough ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to go slower .
# ===============================================
# Step: 18000 Loss: 0.6574704051017761
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s worth a fortune .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is for my friend .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> aren t you anxious ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to be brave , tom .
# ===============================================
# Step: 18200 Loss: 0.6518744230270386
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> he is very depressed .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> tom finished the race .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> can t we start over ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to be on time .
# ===============================================
# Step: 18400 Loss: 0.6914868354797363
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s too hot .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is my house .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> is tom with you ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try on this sweater .
# ===============================================
# Step: 18600 Loss: 0.6519967913627625
# Input: <start> hace mucho frio aqui . <end>
# Predicted translation: <start> <start> it s a fine day today .
# Input: <start> esta es mi vida . <end>
# Predicted translation: <start> <start> this is a law .
# Input: <start> ¿ todavia estan en casa ? <end>
# Predicted translation: <start> <start> can i have some ?
# Input: <start> trata de averiguarlo . <end>
# Predicted translation: <start> <start> try to figure it out .
# ===============================================
